# %%
import pandas as pd

# %%
df = pd.read_csv('CSVFiles/Bitstamp_BTCUSD_2021_minute.csv')
# 2018-05-15 06:00:00 to 2022-04-12 00:00:00
# Out:
# /tmp/ipykernel_12591/1462417771.py:1: DtypeWarning: Columns (0,3,4,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('CSVFiles/Bitstamp_BTCUSD_2021_minute.csv')

# %%
df
# Out:
#                                                                                        https://www.CryptoDataDownload.com
# unix       date                symbol  open     high     low      close    Volume BTC                          Volume USD
# 1647863040 2022-03-21 11:44:00 BTC/USD 41292.70 41292.70 41271.28 41282.43 0.01076342                  444.34013271059996
# 1647862980 2022-03-21 11:43:00 BTC/USD 41293.07 41296.17 41293.07 41293.53 0.48401356                    19986.6284602668
# 1647862920 2022-03-21 11:42:00 BTC/USD 41264.06 41282.03 41260.81 41282.03 0.31252288                    12901.5789078464
# 1647862860 2022-03-21 11:41:00 BTC/USD 41274.15 41274.15 41273.33 41274.15 0.00705745                      291.2902499175
# ...                                                                                                                   ...
# 1609459500 2021-01-01 00:05:00 BTC/USD 29021.86 29023.38 28982.33 28999.5  1.06235967                         30807.89925
# ...
