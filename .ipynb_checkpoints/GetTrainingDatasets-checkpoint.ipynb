# %%
import tensorflow as tf 
# Get the GPU device name.
device_name = tf.test.gpu_device_name()

# The device name should look like the following:
if device_name == '/device:GPU:0':
    print('Found GPU at: {}'.format(device_name))
else:
    raise SystemError('GPU device not found')
# Out:
# 2022-04-15 10:23:57.587307: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Found GPU at: /device:GPU:0
# 2022-04-15 10:23:58.601661: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-15 10:23:58.602700: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-04-15 10:23:58.629995: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-15 10:23:58.630265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1070 computeCapability: 6.1
# coreClock: 1.7845GHz coreCount: 15 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 238.66GiB/s
# 2022-04-15 10:23:58.630277: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-15 10:23:58.631404: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-15 10:23:58.631428: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-15 10:23:58.632477: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-15 10:23:58.632641: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-15 10:23:58.633819: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-15 10:23:58.634469: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-15 10:23:58.636919: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-15 10:23:58.637005: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-15 10:23:58.637302: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-15 10:23:58.637402: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-04-15 10:23:58.637425: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-15 10:23:58.986884: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-15 10:23:58.986906: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-04-15 10:23:58.986911: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-04-15 10:23:58.987063: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-15 10:23:58.987247: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-15 10:23:58.987358: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-15 10:23:58.987449: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/device:GPU:0 with 6540 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2022-04-15 10:23:58.987651: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
import pandas as pd

# %%
df_new = pd.read_csv('CSVFiles/bitcointweets-new.csv')
df_new.drop()

# %%
cols = ["date", "tweet", "user_name"]
# Out:
#        Fri Mar 23 00:40:32 +0000 2018  \
# 0      Fri Mar 23 00:40:34 +0000 2018
# 1      Fri Mar 23 00:40:35 +0000 2018
# 2      Fri Mar 23 00:40:36 +0000 2018
# 3      Fri Mar 23 00:40:36 +0000 2018
# 4      Fri Mar 23 00:40:36 +0000 2018
# ...                               ...
# 50853  Fri Mar 23 08:55:16 +0000 2018
# 50854  Fri Mar 23 08:55:17 +0000 2018
# 50855  Fri Mar 23 08:55:18 +0000 2018
# 50856  Fri Mar 23 08:55:19 +0000 2018
# 50857  Fri Mar 23 08:55:19 +0000 2018
#
#       RT @ALXTOKEN: Paul Krugman, Nobel Luddite. I had to tweak the nose of this Bitcoin enemy. He says such foolish things. Here's the link: htt…  \
# 0      @lopp @_Kevin_Pham @psycho_sage @naval But @Pr...
# 1      RT @tippereconomy: Another use case for #block...
# 2                     free coins https://t.co/DiuoePJdap
# 3      RT @payvxofficial: WE are happy to announce th...
# 4      Copy successful traders automatically with Bit...
# ...                                                  ...
# 50853  RT @fixy_app: Fixy Network brings popular cryp...
# 50854  RT @bethereumteam: After a successful launch o...
# 50855  RT @GymRewards: Buy #GYMRewards Tokens, Bonus ...
# 50856  I added a video to a @YouTube playlist https:/...
# 50857  RT @Raybambs: Airdrop PhotoCoin Airdrop Round#...
#
#         myresumerocket  16522  0  \
# 0             BitMocro   1295  0
# 1         hojachotopur   6090  0
# 2        denies_distro   2626  0
# 3           aditzgraha    184  0
# 4      VictorS61164810     14  0
# ...                ...    ... ..
# 50853    quoting_lives   5673  0
# 50854       VariPewitt    372  0
# 50855     urbancoinerz    557  0
# 50856   MRDanishShahab      3  0
# 50857        Azriel020   1271  0
#
#                                                       []  \
# 0                                           [u'Bitcoin']
# 1           [u'blockchain', u'Tipper', u'TipperEconomy']
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 50853                                                 []
# 50854                                                 []
# 50855  [u'GYMRewards', u'ICO', u'cryptocurrency', u'm...
# 50856                                                 []
# 50857                                     [u'PhotoCoin']
#
#       <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>  \
# 0      <a href="http://twitter.com/download/android" ...
# 1      <a href="http://twitter.com" rel="nofollow">Tw...
# 2      <a href="http://twitter.com" rel="nofollow">Tw...
# 3      <a href="http://twitter.com/download/android" ...
# 4      <a href="http://twitter.com" rel="nofollow">Tw...
# ...                                                  ...
# 50853  <a href="http://twitter.com" rel="nofollow">Tw...
# 50854  <a href="http://twitter.com" rel="nofollow">Tw...
# 50855  <a href="http://twitter.com" rel="nofollow">Tw...
# 50856  <a href="http://www.google.com/" rel="nofollow...
# 50857  <a href="http://twitter.com/download/android" ...
#
#         ['neutral']
# 0       ['neutral']
# 1      ['positive']
# 2      ['positive']
# 3      ['positive']
# 4      ['positive']
# ...             ...
# 50853  ['positive']
# 50854  ['positive']
# 50855   ['neutral']
# 50856  ['positive']
# 50857  ['positive']
#
# [50858 rows x 8 columns]
